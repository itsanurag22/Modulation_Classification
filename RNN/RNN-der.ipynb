# %%
import tarfile
import numpy as np
from keras.utils import np_utils
import keras.models as models
from keras import metrics, Model
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, Input, Add, BatchNormalization, Dropout, Reshape, ZeroPadding2D
from keras.regularizers import *
from keras.optimizers import adam, Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt
import seaborn as sns
import pickle, random, sys, keras
import h5py
import matplotlib.pyplot as plt

# %%
tar = tarfile.open("./RML2016.10a.tar.bz2", "r:bz2")  
tar.extractall()

# %%
with open("RML2016.10a_dict.pkl", "rb") as p:
    dataset = pickle.load(p, encoding='latin1')

# %%
snrs,mods = map(lambda j: sorted(list(set(map(lambda x: x[j], dataset.keys())))), [1,0])

# %%
X = []  
labels = []

# %%
for mod in mods:
    for snr in snrs:
        X.append(dataset[(mod,snr)])
        for i in range(dataset[(mod,snr)].shape[0]):  
            labels.append((mod,snr))

# %%
d = np.vstack(X)

raw = d
derivative = np.gradient(d, axis=-1)
fft = np.abs(np.fft.fft(d, axis=-1))
fft_deriv = np.abs(np.fft.fft(np.gradient(d, axis=-1), axis=-1))

# Concatenate different forms of signal vectors
raw_fft = np.concatenate((raw, fft), axis=-1)
raw_fft_deriv = np.concatenate((raw, fft, fft_deriv), axis=-1)

# %%
# data = raw
data = derivative
# data = raw_fft
# data = raw_fft_deriv

# %%
np.random.seed(2016)
n_examples = data.shape[0]
n_train = n_examples * 0.8
train_idx = np.random.choice(range(0,n_examples), size=int(n_train), replace=False)
test_idx = list(set(range(0,n_examples))-set(train_idx))
X_train = data[train_idx]
X_test =  data[test_idx]

# %%
def to_onehot(yy):
    yy1 = np.zeros([len(yy), max(yy)+1])
    yy1[np.arange(len(yy)),yy] = 1
    return yy1

# %%
Y_train = to_onehot(list(map(lambda x: mods.index(labels[x][0]), train_idx)))
Y_test = to_onehot(list(map(lambda x: mods.index(labels[x][0]), test_idx)))

# %%
inp_shape = list(X_train.shape[1:])
classes = mods

# %%
x = Input(shape=(2,128,1))
y = Conv2D(256, (1, 3), activation='relu', padding='same', kernel_initializer='glorot_uniform')(x)
y = Dropout(0.6)(y)
y = Conv2D(256, (2, 3), activation='relu', padding='same', kernel_initializer='glorot_uniform')(y)   
z = Add()([x, y])
z = Conv2D(80, (1, 3), activation='relu', padding='same', kernel_initializer='glorot_uniform')(z)
z = Dropout(0.6)(z)
z = Conv2D(80, (1, 3), activation='relu', padding='same', kernel_initializer='glorot_uniform')(z)
z = Dropout(0.6)(z)
zz = Flatten()(z)
z = Dense(128, activation='relu', kernel_initializer='he_normal')(zz)
z = Dropout(0.6)(z)
z = Dense(11, activation='softmax', kernel_initializer='he_normal')(z)
model = Model(x,z)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 2, 128, 1)]  0           []
#
#  conv2d_4 (Conv2D)              (None, 2, 128, 256)  1024        ['input_2[0][0]']
#
#  dropout_4 (Dropout)            (None, 2, 128, 256)  0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 2, 128, 256)  393472      ['dropout_4[0][0]']
#
#  add_1 (Add)                    (None, 2, 128, 256)  0           ['input_2[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 2, 128, 80)   61520       ['add_1[0][0]']
#
#  dropout_5 (Dropout)            (None, 2, 128, 80)   0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 2, 128, 80)   19280       ['dropout_5[0][0]']
#
#  dropout_6 (Dropout)            (None, 2, 128, 80)   0           ['conv2d_7[0][0]']
#
#  flatten_1 (Flatten)            (None, 20480)        0           ['dropout_6[0][0]']
#
#  dense_2 (Dense)                (None, 128)          2621568     ['flatten_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 128)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 11)           1419        ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 3,098,283
# Trainable params: 3,098,283
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
opt = Adam(learning_rate=0.0001)
model.compile(optimizer=opt, loss="categorical_crossentropy", metrics=["accuracy"])

# %%
checkpoint_filepath = "best_model.h5"
checkpoint_callback = ModelCheckpoint(checkpoint_filepath, monitor="val_accuracy", save_best_only=True, verbose=0)
reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=20, verbose=1, min_delta=1e-4, mode='min')

# %%
history = model.fit(
    X_train,
    Y_train,
    epochs=15,
    batch_size=128,
    validation_data=(X_test, Y_test),
    callbacks=[checkpoint_callback, reduce_lr_loss]
)
# Out:
# Epoch 1/15
# 1375/1375 [==============================] - 878s 639ms/step - loss: 2.2584 - accuracy: 0.1801 - val_loss: 2.0078 - val_accuracy: 0.2098 - lr: 1.0000e-04
# Epoch 2/15
# 1375/1375 [==============================] - 893s 650ms/step - loss: 1.9474 - accuracy: 0.2697 - val_loss: 1.8869 - val_accuracy: 0.2945 - lr: 1.0000e-04
# Epoch 3/15
# 1375/1375 [==============================] - 895s 651ms/step - loss: 1.8333 - accuracy: 0.3126 - val_loss: 1.8022 - val_accuracy: 0.3136 - lr: 1.0000e-04
# Epoch 4/15
# 1375/1375 [==============================] - 890s 648ms/step - loss: 1.7593 - accuracy: 0.3344 - val_loss: 1.7253 - val_accuracy: 0.3370 - lr: 1.0000e-04
# Epoch 5/15
# 1375/1375 [==============================] - 889s 647ms/step - loss: 1.7199 - accuracy: 0.3451 - val_loss: 1.7142 - val_accuracy: 0.3367 - lr: 1.0000e-04
# Epoch 6/15
# 1375/1375 [==============================] - 858s 624ms/step - loss: 1.6989 - accuracy: 0.3509 - val_loss: 1.6642 - val_accuracy: 0.3544 - lr: 1.0000e-04
# Epoch 7/15
# 1375/1375 [==============================] - 896s 652ms/step - loss: 1.6834 - accuracy: 0.3560 - val_loss: 1.6741 - val_accuracy: 0.3461 - lr: 1.0000e-04
# Epoch 8/15
# 1375/1375 [==============================] - 1035s 753ms/step - loss: 1.6747 - accuracy: 0.3580 - val_loss: 1.6790 - val_accuracy: 0.3490 - lr: 1.0000e-04
# Epoch 9/15
# 1375/1375 [==============================] - 859s 625ms/step - loss: 1.6666 - accuracy: 0.3602 - val_loss: 1.6696 - val_accuracy: 0.3501 - lr: 1.0000e-04
# Epoch 10/15
# 1375/1375 [==============================] - 842s 613ms/step - loss: 1.6585 - accuracy: 0.3622 - val_loss: 1.6028 - val_accuracy: 0.3746 - lr: 1.0000e-04
# Epoch 11/15
# 1375/1375 [==============================] - 839s 611ms/step - loss: 1.6515 - accuracy: 0.3636 - val_loss: 1.6358 - val_accuracy: 0.3597 - lr: 1.0000e-04
# Epoch 12/15
# 1375/1375 [==============================] - 870s 633ms/step - loss: 1.6462 - accuracy: 0.3652 - val_loss: 1.6132 - val_accuracy: 0.3682 - lr: 1.0000e-04
# Epoch 13/15
# 1375/1375 [==============================] - 836s 608ms/step - loss: 1.6387 - accuracy: 0.3663 - val_loss: 1.6339 - val_accuracy: 0.3586 - lr: 1.0000e-04
# Epoch 14/15
# 1375/1375 [==============================] - 860s 625ms/step - loss: 1.6312 - accuracy: 0.3684 - val_loss: 1.6101 - val_accuracy: 0.3666 - lr: 1.0000e-04
# Epoch 15/15
# 1375/1375 [==============================] - 860s 625ms/step - loss: 1.6244 - accuracy: 0.3704 - val_loss: 1.5985 - val_accuracy: 0.3671 - lr: 1.0000e-04

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test accuracy:", test_acc)
# Out:
# 1375/1375 [==============================] - 77s 56ms/step - loss: 1.5985 - accuracy: 0.3671
# Test accuracy: 0.36706817150115967

# %%
plt.plot(history.history["accuracy"], label = 'Train accuracy', marker='o')
plt.plot(history.history["val_accuracy"], label = 'Validation accuracy', marker='o')
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.figure()
plt.title('Training performance')
plt.plot(history.epoch, history.history['loss'], label='train loss+error', marker='o')
plt.plot(history.epoch, history.history['val_loss'], label='val_error', marker='o')
plt.legend()

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues, labels=[]):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
acc = {}
for snr in snrs:    
    test_SNRs = list(map(lambda x: labels[x][1], test_idx))
    test_X_i = X_test[np.where(np.array(test_SNRs)==snr)]
    test_Y_i = Y_test[np.where(np.array(test_SNRs)==snr)]    
    test_Y_hat = model.predict(test_X_i, batch_size=100)
    conf = np.zeros([len(classes),len(classes)])
    confnorm = np.zeros([len(classes),len(classes)])
    for i in range(0,test_X_i.shape[0]):
        j = list(test_Y_i[i,:]).index(1)
        k = int(np.argmax(test_Y_hat[i,:]))
        conf[j,k] = conf[j,k] + 1
    for i in range(0,len(classes)):
        confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])
    plt.figure()
    plot_confusion_matrix(confnorm, labels=classes, title="CNN Confusion Matrix (SNR=%d)"%(snr))
    
    cor = np.sum(np.diag(conf))
    ncor = np.sum(conf) - cor
    print ("Overall Accuracy for SNR=%d: "%(snr), 1.0 * cor / (cor+ncor))
    acc[snr] = 1.0*cor/(cor+ncor)
# Out:
# 23/23 [==============================] - 3s 122ms/step
# Overall Accuracy for SNR=-20:  0.0861913357400722
# 23/23 [==============================] - 3s 117ms/step
# Overall Accuracy for SNR=-18:  0.09623241034952337
# 22/22 [==============================] - 3s 128ms/step
# Overall Accuracy for SNR=-16:  0.08207934336525308
# 22/22 [==============================] - 3s 125ms/step
# Overall Accuracy for SNR=-14:  0.08777573529411764
# 23/23 [==============================] - 3s 123ms/step
# Overall Accuracy for SNR=-12:  0.1084715374271627
# 23/23 [==============================] - 3s 127ms/step
# Overall Accuracy for SNR=-10:  0.15253496503496503
# 21/21 [==============================] - 3s 131ms/step
# Overall Accuracy for SNR=-8:  0.23809523809523808
# 23/23 [==============================] - 3s 129ms/step
# Overall Accuracy for SNR=-6:  0.34081724292770543
# 22/22 [==============================] - 4s 165ms/step
# Overall Accuracy for SNR=-4:  0.42417061611374407
# 23/23 [==============================] - 4s 170ms/step
# Overall Accuracy for SNR=-2:  0.4896155545735749
# 23/23 [==============================] - 4s 161ms/step
# Overall Accuracy for SNR=0:  0.5270209915140688
# 22/22 [==============================] - 4s 161ms/step
# Overall Accuracy for SNR=2:  0.5129509713228492
# 22/22 [==============================] - 3s 156ms/step
# Overall Accuracy for SNR=4:  0.5359596885020614
# 22/22 [==============================] - 4s 171ms/step
# Overall Accuracy for SNR=6:  0.5313921747042766
# 23/23 [==============================] - 4s 158ms/step
# Overall Accuracy for SNR=8:  0.5070422535211268
# 23/23 [==============================] - 4s 158ms/step
# Overall Accuracy for SNR=10:  0.5181159420289855
# 23/23 [==============================] - 4s 160ms/step
# Overall Accuracy for SNR=12:  0.517428700769579
# 22/22 [==============================] - 3s 152ms/step
# Overall Accuracy for SNR=14:  0.5271713887598699
# 22/22 [==============================] - 3s 134ms/step
# Overall Accuracy for SNR=16:  0.5255009107468124
# 23/23 [==============================] - 3s 144ms/step
# Overall Accuracy for SNR=18:  0.5369875222816399

# %%
plt.plot(snrs, list(map(lambda x: acc[x], snrs)), marker='o')
plt.xlabel("Signal to Noise Ratio")
plt.ylabel("Classification Accuracy")
plt.title("CNN Classification Accuracy")
# Out:
# Text(0.5, 1.0, 'CNN Classification Accuracy')
