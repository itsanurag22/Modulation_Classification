# %%
import tarfile
import numpy as np
from keras.utils import np_utils
import keras.models as models
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Dropout, Reshape, ZeroPadding2D
from keras.regularizers import *
from keras.optimizers import adam, Adam
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import seaborn as sns
import pickle, random, sys, keras
import h5py
import matplotlib.pyplot as plt

# %%
tar = tarfile.open("./RML2016.10a.tar.bz2", "r:bz2")  
tar.extractall()

# %%
with open("RML2016.10a_dict.pkl", "rb") as p:
    dataset = pickle.load(p, encoding='latin1')

# %%
snrs,mods = map(lambda j: sorted(list(set(map(lambda x: x[j], dataset.keys())))), [1,0])

# %%
X = []  
labels = []

# %%
for mod in mods:
    for snr in snrs:
        X.append(dataset[(mod,snr)])
        for i in range(dataset[(mod,snr)].shape[0]):  
            labels.append((mod,snr))

# %%
d = np.vstack(X)

raw = d
derivative = np.gradient(d, axis=-1)
fft = np.abs(np.fft.fft(d, axis=-1))
fft_deriv = np.abs(np.fft.fft(np.gradient(d, axis=-1), axis=-1))

# Concatenate different forms of signal vectors
raw_fft = np.concatenate((raw, fft), axis=-1)
raw_fft_deriv = np.concatenate((raw, fft, fft_deriv), axis=-1)

# %%
data = raw
# data = derivative
# data = raw_fft
# data = raw_fft_deriv

# %%
np.random.seed(2016)
n_examples = data.shape[0]
n_train = n_examples * 0.8
train_idx = np.random.choice(range(0,n_examples), size=int(n_train), replace=False)
test_idx = list(set(range(0,n_examples))-set(train_idx))
X_train = data[train_idx]
X_test =  data[test_idx]

# %%
def to_onehot(yy):
    yy1 = np.zeros([len(yy), max(yy)+1])
    yy1[np.arange(len(yy)),yy] = 1
    return yy1

# %%
Y_train = to_onehot(list(map(lambda x: mods.index(labels[x][0]), train_idx)))
Y_test = to_onehot(list(map(lambda x: mods.index(labels[x][0]), test_idx)))

# %%
inp_shape = list(X_train.shape[1:])
classes = mods
inp_shape
# Out:
# [2, 128]

# %%
model = models.Sequential()
model.add(Flatten(input_shape=inp_shape))
model.add(Dense(128, activation='relu', kernel_initializer='glorot_uniform'))
model.add(Dense(64, activation='relu', kernel_initializer='glorot_uniform'))
model.add(BatchNormalization(1))
model.add(Dense(32, activation='relu', kernel_initializer='glorot_uniform'))
model.add(Dropout(0.1))
model.add(Dense(11, activation='softmax', kernel_initializer='glorot_uniform'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 128)               32896
#
#  dense_9 (Dense)             (None, 64)                8256
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_10 (Dense)            (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_11 (Dense)            (None, 11)                363
#
# =================================================================
# Total params: 43,851
# Trainable params: 43,723
# Non-trainable params: 128
# _________________________________________________________________

# %%
opt = Adam(learning_rate=0.0001)
model.compile(optimizer=opt, loss="categorical_crossentropy", metrics=["accuracy"])

# %%
checkpoint_filepath = "best_model.h5"
checkpoint_callback = ModelCheckpoint(checkpoint_filepath, monitor="val_accuracy", save_best_only=True, verbose=0)

# %%
history = model.fit(
    X_train,
    Y_train,
    epochs=30,
    batch_size=100,
    validation_data=(X_test, Y_test),
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/30
# 1760/1760 [==============================] - 4s 2ms/step - loss: 2.2058 - accuracy: 0.1794 - val_loss: 2.1053 - val_accuracy: 0.2278
# Epoch 2/30
# 1760/1760 [==============================] - 3s 2ms/step - loss: 2.0000 - accuracy: 0.2627 - val_loss: 1.9012 - val_accuracy: 0.2932
# Epoch 3/30
# 1760/1760 [==============================] - 3s 2ms/step - loss: 1.8653 - accuracy: 0.3027 - val_loss: 1.8236 - val_accuracy: 0.3182
# Epoch 4/30
# 1760/1760 [==============================] - 3s 2ms/step - loss: 1.8065 - accuracy: 0.3225 - val_loss: 1.7818 - val_accuracy: 0.3301
# Epoch 5/30
# 1760/1760 [==============================] - 4s 2ms/step - loss: 1.7700 - accuracy: 0.3336 - val_loss: 1.7541 - val_accuracy: 0.3370
# Epoch 6/30
# 1760/1760 [==============================] - 3s 2ms/step - loss: 1.7440 - accuracy: 0.3419 - val_loss: 1.7338 - val_accuracy: 0.3450
# Epoch 7/30
# 1760/1760 [==============================] - 4s 2ms/step - loss: 1.7211 - accuracy: 0.3488 - val_loss: 1.7158 - val_accuracy: 0.3510
# Epoch 8/30
# 1760/1760 [==============================] - 4s 2ms/step - loss: 1.6996 - accuracy: 0.3565 - val_loss: 1.6985 - val_accuracy: 0.3573
# Epoch 9/30
# 1760/1760 [==============================] - 4s 2ms/step - loss: 1.6801 - accuracy: 0.3617 - val_loss: 1.6842 - val_accuracy: 0.3603
# Epoch 10/30
# 1760/1760 [==============================] - 4s 2ms/step - loss: 1.6620 - accuracy: 0.3685 - val_loss: 1.6676 - val_accuracy: 0.3635
# Epoch 11/30
# 1760/1760 [==============================] - 5s 3ms/step - loss: 1.6439 - accuracy: 0.3719 - val_loss: 1.6521 - val_accuracy: 0.3662
# Epoch 12/30
# 1760/1760 [==============================] - 6s 3ms/step - loss: 1.6258 - accuracy: 0.3780 - val_loss: 1.6359 - val_accuracy: 0.3756
# Epoch 13/30
# 1760/1760 [==============================] - 6s 3ms/step - loss: 1.6083 - accuracy: 0.3846 - val_loss: 1.6217 - val_accuracy: 0.3796
# Epoch 14/30
# 1760/1760 [==============================] - 5s 3ms/step - loss: 1.5923 - accuracy: 0.3906 - val_loss: 1.6078 - val_accuracy: 0.3879
# Epoch 15/30
# 1760/1760 [==============================] - 5s 3ms/step - loss: 1.5781 - accuracy: 0.3964 - val_loss: 1.5995 - val_accuracy: 0.3911
# Epoch 16/30
# 1760/1760 [==============================] - 5s 3ms/step - loss: 1.5642 - accuracy: 0.4014 - val_loss: 1.5884 - val_accuracy: 0.3935
# Epoch 17/30
# 1760/1760 [==============================] - 5s 3ms/step - loss: 1.5516 - accuracy: 0.4052 - val_loss: 1.5818 - val_accuracy: 0.3959
# Epoch 18/30
# 1760/1760 [==============================] - 4s 2ms/step - loss: 1.5426 - accuracy: 0.4082 - val_loss: 1.5738 - val_accuracy: 0.3976
# Epoch 19/30
# 1760/1760 [==============================] - 4s 2ms/step - loss: 1.5330 - accuracy: 0.4122 - val_loss: 1.5710 - val_accuracy: 0.3988
# Epoch 20/30
# 1760/1760 [==============================] - 4s 2ms/step - loss: 1.5221 - accuracy: 0.4148 - val_loss: 1.5614 - val_accuracy: 0.4030
# Epoch 21/30
# 1760/1760 [==============================] - 5s 3ms/step - loss: 1.5137 - accuracy: 0.4178 - val_loss: 1.5533 - val_accuracy: 0.4092
# Epoch 22/30
# 1760/1760 [==============================] - 6s 3ms/step - loss: 1.5032 - accuracy: 0.4217 - val_loss: 1.5490 - val_accuracy: 0.4121
# Epoch 23/30
# 1760/1760 [==============================] - 5s 3ms/step - loss: 1.4924 - accuracy: 0.4250 - val_loss: 1.5390 - val_accuracy: 0.4128
# Epoch 24/30
# 1760/1760 [==============================] - 5s 3ms/step - loss: 1.4814 - accuracy: 0.4304 - val_loss: 1.5313 - val_accuracy: 0.4142
# Epoch 25/30
# 1760/1760 [==============================] - 4s 2ms/step - loss: 1.4708 - accuracy: 0.4327 - val_loss: 1.5209 - val_accuracy: 0.4187
# Epoch 26/30
# 1760/1760 [==============================] - 4s 2ms/step - loss: 1.4586 - accuracy: 0.4368 - val_loss: 1.5092 - val_accuracy: 0.4253
# Epoch 27/30
# 1760/1760 [==============================] - 4s 2ms/step - loss: 1.4476 - accuracy: 0.4408 - val_loss: 1.5094 - val_accuracy: 0.4209
# Epoch 28/30
# 1760/1760 [==============================] - 5s 3ms/step - loss: 1.4360 - accuracy: 0.4439 - val_loss: 1.4927 - val_accuracy: 0.4303
# Epoch 29/30
# 1760/1760 [==============================] - 5s 3ms/step - loss: 1.4271 - accuracy: 0.4468 - val_loss: 1.4867 - val_accuracy: 0.4336
# Epoch 30/30
# 1760/1760 [==============================] - 6s 3ms/step - loss: 1.4182 - accuracy: 0.4506 - val_loss: 1.4836 - val_accuracy: 0.4336

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test accuracy:", test_acc)
# Out:
# 1375/1375 [==============================] - 1s 967us/step - loss: 1.4836 - accuracy: 0.4336
# Test accuracy: 0.4336136281490326

# %%
plt.plot(history.history["accuracy"], label = 'Train accuracy', marker='o')
plt.plot(history.history["val_accuracy"], label = 'Validation accuracy', marker='o')
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.figure()
plt.title('Training performance')
plt.plot(history.epoch, history.history['loss'], label='train loss+error', marker='o')
plt.plot(history.epoch, history.history['val_loss'], label='val_error', marker='o')
plt.legend()

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues, labels=[]):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
acc = {}
for snr in snrs:    
    test_SNRs = list(map(lambda x: labels[x][1], test_idx))
    test_X_i = X_test[np.where(np.array(test_SNRs)==snr)]
    test_Y_i = Y_test[np.where(np.array(test_SNRs)==snr)]    
    test_Y_hat = model.predict(test_X_i, batch_size=100)
    conf = np.zeros([len(classes),len(classes)])
    confnorm = np.zeros([len(classes),len(classes)])
    for i in range(0,test_X_i.shape[0]):
        j = list(test_Y_i[i,:]).index(1)
        k = int(np.argmax(test_Y_hat[i,:]))
        conf[j,k] = conf[j,k] + 1
    for i in range(0,len(classes)):
        confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])
    plt.figure()
    plot_confusion_matrix(confnorm, labels=classes, title="CNN Confusion Matrix (SNR=%d)"%(snr))
    
    cor = np.sum(np.diag(conf))
    ncor = np.sum(conf) - cor
    print ("Overall Accuracy for SNR=%d: "%(snr), 1.0 * cor / (cor+ncor))
    acc[snr] = 1.0*cor/(cor+ncor)
# Out:
# 23/23 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=-20:  0.08754512635379061
# 23/23 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=-18:  0.09123921924648207
# 22/22 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=-16:  0.09211126310989512
# 22/22 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=-14:  0.09696691176470588
# 23/23 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=-12:  0.11653966831017482
# 23/23 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=-10:  0.16477272727272727
# 21/21 [==============================] - 0s 2ms/step
# Overall Accuracy for SNR=-8:  0.24714285714285714
# 23/23 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=-6:  0.3834755276156264
# 22/22 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=-4:  0.5123222748815166
# 23/23 [==============================] - 0s 2ms/step
# Overall Accuracy for SNR=-2:  0.6018559434379143
# 23/23 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=0:  0.617686467172845
# 22/22 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=2:  0.6225716928769658
# 22/22 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=4:  0.6275767292716445
# 22/22 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=6:  0.637852593266606
# 23/23 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=8:  0.6183552930486143
# 23/23 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=10:  0.6326992753623188
# 23/23 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=12:  0.6301493888637393
# 22/22 [==============================] - 0s 1ms/step
# Overall Accuracy for SNR=14:  0.6335346028797028
# 22/22 [==============================] - 0s 2ms/step
# Overall Accuracy for SNR=16:  0.6234061930783242
# 23/23 [==============================] - 0s 2ms/step
# Overall Accuracy for SNR=18:  0.6390374331550802

# %%
plt.plot(snrs, list(map(lambda x: acc[x], snrs)), marker='o')
plt.xlabel("Signal to Noise Ratio")
plt.ylabel("Classification Accuracy")
plt.title("CNN Classification Accuracy")
# Out:
# Text(0.5, 1.0, 'CNN Classification Accuracy')
